# %% [markdown]
# # CIFAR10 Classification Problem

# %% [markdown]
# 🎯 **Exercise objectives**
#
# * 1️⃣ Implement a CNN to solve a **`10-class classification problem`**
#
# * 2️⃣ Enhance the CNN's performance with **`Data Augmentation Techniques`**
#
# * 3️⃣ Experiment with **`GPUs to Accelerate Image Processing using Google Colab`**
#
# <hr>
#
#
# 👏 You should now have a better feeling of:
# * how CNNs works,
# * and especially how convolutions scan images to detect specific spatial features.
#
# 🚀 It's time to play with images that are a bit more complex than the handwritten digits or the triangles/circles.
#
# 🎨 From [Wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) (*click on the link for further information*):
#
# > The **`CIFAR-10`** dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# ⭐️ This dataset is iconic in the research community as many enhancements for image recognition have been achieved on this dataset. After achieving great performance on this dataset, researchers moved to the more advanced CIFAR-100.
#
# From the [University of Toronto](https://www.cs.toronto.edu/~kriz/cifar.html):
#
# > This dataset is just like the CIFAR-10, except it has 100 classes containing 600 images each. There are 500 training images and 100 testing images per class. The 100 classes in the CIFAR-100 are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs).
#
#
# 🔥 In this notebook, let's ***implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset***.
#
# ❗️ Again, remember that until 10 years ago, this problem was very challenging for the entire research community. As you have been sharpening your CNN skills, it is time to shine!

# %% [markdown]
# ## 🛠 Google Colab Setup

# %% [markdown]
# If you are planning to use Google Colab (which is strongly recommended for this challenge), there is a few things you need to take care of first so that you can run everything properly.
#
# * If you want to get started, follow these four steps.
# * You can also read Davy's tutorial on Kitt 👉 [Introduction to Google Colab](https://kitt.lewagon.com/knowledge/tutorials/data_google_colab)

# %% [markdown]
# ### Step 1: Upload the Challenge Folder to Google Drive and Open it in Colab

# %% [markdown]
# If you want Google Colab to be able to run this notebook, you need to ***upload all the necessary files to your Google Drive***.
#
# To do this, simply:
# 1. Access your [Google Drive](https://drive.google.com/)
# 2. Go into the `Colab Notebooks folder`
# 3. Drag-and-drop this `challenge's folder` into it
# 4. Right-click the notebook file and select `Open with` $\rightarrow$ `Google Colaboratory`

# %% [markdown]
# ### Step 2: Mount Google Drive

# %% [markdown]
# The previous was necessary but not enough. For security purposes, Google Colab and Google Drive are NOT connected even if they belong to the same Google Account
#
# We need to ***mount the main directory of the Google Drive associated with the account being used for Colab***.
#
# *Note: if you're getting errors when authenticating, try to do it in Google Chrome, as other browsers tend to experience issues.*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ⬅️ On the left sidebar, there is a 🗂 folder icon.
# * If you click on it, you should now see a folder called `drive/MyDrive`. This is your Google Drive and all its content!

# %% [markdown]
# ### Step 3: Navigate to the Challenge Directory

# %% [markdown]
# One more thing: we need to  this notebook in the context of the challenge's folder.
#
# Simply run the cell down below.

# %%
import os

# os.chdir allows you to change directories, like cd in the Terminal
os.chdir('/content/drive/MyDrive/Colab Notebooks/data-cifar-classification')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e70cb30fa6f9> in <cell line: 4>()
#       2
#       3 # os.chdir allows you to change directories, like cd in the Terminal
# ----> 4 os.chdir('/content/drive/MyDrive/Colab Notebooks/data-cifar-classification')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/data-cifar-classification'

# %% [markdown]
# ### Step 4: Toggle GPU Acceleration

# %% [markdown]
# As a last step, we should take advantage of Google Colab by enabling GPU acceleration for our notebook.
#
# You can do it by navigating through the menu bar:
#
# `Runtime` $\rightarrow$ `Change runtime type` $\rightarrow$ `Hardware accelerator`
#
# and select "GPU" from the dropdown menu.

# %% [markdown]
# 🚀 You are now ready to start, proceed with the challenge! 🚀

# %% [markdown]
# ## (1) Loading the CIFAR10 Dataset

# %% [markdown]
# ❓ **Question: Loading the CIFAR10 Dataset** ❓
#
#
# * 🎁 We took care of the `data loading and preprocessing` for you.
# * ▶️ Just run the following cell and make sure you understand the code.

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()

labels = ['airplane',
          'automobile',
          'bird',
          'cat',
          'deer',
          'dog',
          'frog',
          'horse',
          'ship',
          'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ### (1.1) Working on a smaller dataset?

# %% [markdown]
# ❓ **Question about the training size** ❓
#
# * It will probably take a very long time to train a model on $50 000$ images m...
# * 👨🏻‍🏫 **Always start with a subsample to iterate quickly** before scaling up! 🆙
# * Run the next cell where we are reducing the dataset size by `reduction_factor = 10`. Don't try to increase it unless we ask you to do so...

# %%
# Considering only 1/10th of the 50_000 images
reduction_factor = 10

# Choosing the random indices of small train set and small test set
idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor), replace=False)
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor), replace=False)

# Collecting the two subsamples images_train_small and images_test_small from images_train and images_test
images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
# and their corresponding labels
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print("------------------ Before -----------------")
print(images_train.shape, images_test.shape)

print("")

print("--- After applying the reduction factor ---")
print(images_train_small.shape, images_test_small.shape)

print("")
print("-"*43)

unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# ------------------ Before -----------------
# (50000, 32, 32, 3) (10000, 32, 32, 3)
#
# --- After applying the reduction factor ---
# (5000, 32, 32, 3) (1000, 32, 32, 3)
#
# -------------------------------------------
# {0: 529,
#  1: 496,
#  2: 515,
#  3: 486,
#  4: 487,
#  5: 481,
#  6: 456,
#  7: 516,
#  8: 513,
#  9: 521}

# %% [markdown]
# 👇 You are working with images.. so it would be a good idea to have a look at some of them :)

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# ### (1.2) Image preprocesing

# %% [markdown]
# 👉 As usual, let's:
# - normalize the pixels' intensities between 0 and 1
# - turn the `labels_train` and `labels_test` into "one-hot-encoded" targets that we will call respectively `y_train` and `y_test`

# %%
### Normalizing pixels' intensities
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

### Encoding the labels
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %%
from scipy.ndimage import convolve
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## (2) Iterate on your CNN architecture using your small training set

# %% [markdown]
# ❓ **Question** ❓ Time to shine ⭐️⭐️⭐️ !
#
# 1. Define the CNN architecture of your choice in an `initialize_model()` function:
# 2. Compile your model in a `compile_model()` method:
# 3. Fit your CNN only on the `small training set` and save the training information in an `history` variable
# ---
# * Feeling lost?
# * Do you want to improve your performance ?
#
# <details>
#     <summary>🆘 PRO TIPS 🆘</summary>
#
#
# - Do not forget to add the **`input shape`** of your images to the first layer: it has 3 colors
# - **`Start simple, add complexify later `** after several attempts to get better results
# - The task is complex: **`Try at least 3 or 4 convolutions`**, you want your **images to go through different magnifying glasses / kernels from different convolutional layers!**
# - The Kernel Size does not need to be large for such a small picture resolution!
# - Add some **`MaxPooling2D`** (but not too much, otherwise the activation "image" will become too small)
# - Keep `padding = "same"` and `stride = (1,1)` to start with.
# - Once your model overfits, try to add some **`Dropout Layers` to regularize the network**. A good tip is to **increase the Dropout Rate/Strength as you move closer to the prediction layer** to prevent your CNN from overfitting
# - Images are so small in CIFAR10, you can afford to use a larger batch size (32 or 64) to benefit even more from **GPU parallelization**!
# </details>
#
# ---

# %%
def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    model= Sequential()
    model.add(layers.Conv2D(32, kernel_size= (3,3), input_shape= (32,32,3), padding='same', strides=(1,1) ,activation= 'relu'))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    model.add(layers.Conv2D(32, kernel_size= (3,3), padding='same', activation= 'relu'))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    model.add(layers.Conv2D(64, kernel_size= (3,3), padding='same', activation= 'relu'))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    model.add(layers.Conv2D(64, kernel_size= (3,3), padding='same', activation= 'relu'))
    model.add(layers.MaxPool2D(pool_size=(2,2)))


    model.add(layers.Flatten())
    model.add(layers.Dense(50, activation= 'relu'))
    model.add(layers.Dropout(rate=0.3))
    model.add(layers.Dense(10, activation= 'relu'))
    model.add(layers.Dropout(rate=0.6))

    model.add(layers.Dense(10, activation='softmax'))


    return model

# %%
def compile_model(model):
    '''return a compiled model suited for the CIFAR-10 task'''

    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
    return model

# %%
model= compile_model(initialize_model())

# %%
es= EarlyStopping(patience=20)
history= model.fit(X_train_small, y_train_small, validation_split= 0.2, batch_size= 32, epochs= 200, callbacks=[es])
# Out:
# Epoch 1/200
# 125/125 [==============================] - 3s 7ms/step - loss: 2.3035 - accuracy: 0.0993 - val_loss: 2.3010 - val_accuracy: 0.1060
# Epoch 2/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.3013 - accuracy: 0.0997 - val_loss: 2.2988 - val_accuracy: 0.1120
# Epoch 3/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.2982 - accuracy: 0.1082 - val_loss: 2.2933 - val_accuracy: 0.1130
# Epoch 4/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.2941 - accuracy: 0.1085 - val_loss: 2.2857 - val_accuracy: 0.1220
# Epoch 5/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.2899 - accuracy: 0.1290 - val_loss: 2.2823 - val_accuracy: 0.1380
# Epoch 6/200
# 125/125 [==============================] - 1s 8ms/step - loss: 2.2858 - accuracy: 0.1248 - val_loss: 2.2765 - val_accuracy: 0.1660
# Epoch 7/200
# 125/125 [==============================] - 1s 7ms/step - loss: 2.2783 - accuracy: 0.1430 - val_loss: 2.2650 - val_accuracy: 0.1750
# Epoch 8/200
# 125/125 [==============================] - 1s 7ms/step - loss: 2.2665 - accuracy: 0.1395 - val_loss: 2.2523 - val_accuracy: 0.1870
# Epoch 9/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.2657 - accuracy: 0.1470 - val_loss: 2.2464 - val_accuracy: 0.1900
# Epoch 10/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.2528 - accuracy: 0.1540 - val_loss: 2.2304 - val_accuracy: 0.1840
# Epoch 11/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.2494 - accuracy: 0.1517 - val_loss: 2.2208 - val_accuracy: 0.2300
# Epoch 12/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.2339 - accuracy: 0.1602 - val_loss: 2.2029 - val_accuracy: 0.2070
# Epoch 13/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.2267 - accuracy: 0.1555 - val_loss: 2.1874 - val_accuracy: 0.2640
# Epoch 14/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.2227 - accuracy: 0.1625 - val_loss: 2.1814 - val_accuracy: 0.3000
# Epoch 15/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.2084 - accuracy: 0.1715 - val_loss: 2.1739 - val_accuracy: 0.2710
# Epoch 16/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.1910 - accuracy: 0.1760 - val_loss: 2.1505 - val_accuracy: 0.2690
# Epoch 17/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.1839 - accuracy: 0.1832 - val_loss: 2.1402 - val_accuracy: 0.2600
# Epoch 18/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.1748 - accuracy: 0.1885 - val_loss: 2.1149 - val_accuracy: 0.2890
# Epoch 19/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.1849 - accuracy: 0.1908 - val_loss: 2.1244 - val_accuracy: 0.3130
# Epoch 20/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.1487 - accuracy: 0.1972 - val_loss: 2.0933 - val_accuracy: 0.3040
# Epoch 21/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.1609 - accuracy: 0.1890 - val_loss: 2.0978 - val_accuracy: 0.3130
# Epoch 22/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.1526 - accuracy: 0.1990 - val_loss: 2.0674 - val_accuracy: 0.3320
# Epoch 23/200
# 125/125 [==============================] - 1s 7ms/step - loss: 2.1419 - accuracy: 0.2007 - val_loss: 2.0779 - val_accuracy: 0.3190
# Epoch 24/200
# 125/125 [==============================] - 1s 7ms/step - loss: 2.1562 - accuracy: 0.2010 - val_loss: 2.0612 - val_accuracy: 0.3300
# Epoch 25/200
# 125/125 [==============================] - 1s 8ms/step - loss: 2.1210 - accuracy: 0.2040 - val_loss: 2.0425 - val_accuracy: 0.3330
# Epoch 26/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.1172 - accuracy: 0.2103 - val_loss: 2.0446 - val_accuracy: 0.3480
# Epoch 27/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0996 - accuracy: 0.2190 - val_loss: 2.0244 - val_accuracy: 0.3320
# Epoch 28/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0898 - accuracy: 0.2342 - val_loss: 2.0120 - val_accuracy: 0.3480
# Epoch 29/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0816 - accuracy: 0.2257 - val_loss: 2.0068 - val_accuracy: 0.3380
# Epoch 30/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0803 - accuracy: 0.2335 - val_loss: 1.9759 - val_accuracy: 0.3580
# Epoch 31/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0867 - accuracy: 0.2205 - val_loss: 1.9952 - val_accuracy: 0.3380
# Epoch 32/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0692 - accuracy: 0.2395 - val_loss: 1.9626 - val_accuracy: 0.3510
# Epoch 33/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0629 - accuracy: 0.2348 - val_loss: 1.9525 - val_accuracy: 0.3640
# Epoch 34/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0443 - accuracy: 0.2460 - val_loss: 1.9312 - val_accuracy: 0.3710
# Epoch 35/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0435 - accuracy: 0.2360 - val_loss: 1.9292 - val_accuracy: 0.3280
# Epoch 36/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0281 - accuracy: 0.2520 - val_loss: 1.9222 - val_accuracy: 0.3700
# Epoch 37/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0194 - accuracy: 0.2510 - val_loss: 1.9175 - val_accuracy: 0.3850
# Epoch 38/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0161 - accuracy: 0.2587 - val_loss: 1.8772 - val_accuracy: 0.3850
# Epoch 39/200
# 125/125 [==============================] - 1s 5ms/step - loss: 2.0016 - accuracy: 0.2670 - val_loss: 1.8808 - val_accuracy: 0.3950
# Epoch 40/200
# 125/125 [==============================] - 1s 6ms/step - loss: 2.0035 - accuracy: 0.2635 - val_loss: 1.8862 - val_accuracy: 0.4020
# Epoch 41/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.9911 - accuracy: 0.2545 - val_loss: 1.8886 - val_accuracy: 0.4280
# Epoch 42/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.9749 - accuracy: 0.2695 - val_loss: 1.8699 - val_accuracy: 0.3970
# Epoch 43/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.9895 - accuracy: 0.2542 - val_loss: 1.8402 - val_accuracy: 0.4020
# Epoch 44/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.9638 - accuracy: 0.2677 - val_loss: 1.8278 - val_accuracy: 0.4230
# Epoch 45/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.9844 - accuracy: 0.2603 - val_loss: 1.8304 - val_accuracy: 0.4100
# Epoch 46/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9574 - accuracy: 0.2702 - val_loss: 1.8191 - val_accuracy: 0.4110
# Epoch 47/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9572 - accuracy: 0.2720 - val_loss: 1.8225 - val_accuracy: 0.4190
# Epoch 48/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9388 - accuracy: 0.2710 - val_loss: 1.8033 - val_accuracy: 0.4170
# Epoch 49/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.9515 - accuracy: 0.2733 - val_loss: 1.7960 - val_accuracy: 0.4300
# Epoch 50/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9452 - accuracy: 0.2620 - val_loss: 1.7823 - val_accuracy: 0.4210
# Epoch 51/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.9338 - accuracy: 0.2865 - val_loss: 1.7795 - val_accuracy: 0.4450
# Epoch 52/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9262 - accuracy: 0.2790 - val_loss: 1.7736 - val_accuracy: 0.4180
# Epoch 53/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9128 - accuracy: 0.2788 - val_loss: 1.7910 - val_accuracy: 0.3930
# Epoch 54/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9143 - accuracy: 0.2833 - val_loss: 1.7663 - val_accuracy: 0.4340
# Epoch 55/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9160 - accuracy: 0.2833 - val_loss: 1.7476 - val_accuracy: 0.4330
# Epoch 56/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.9056 - accuracy: 0.2853 - val_loss: 1.7499 - val_accuracy: 0.4370
# Epoch 57/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8974 - accuracy: 0.2873 - val_loss: 1.7245 - val_accuracy: 0.4440
# Epoch 58/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.8912 - accuracy: 0.2887 - val_loss: 1.7447 - val_accuracy: 0.4130
# Epoch 59/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.8925 - accuracy: 0.2780 - val_loss: 1.7122 - val_accuracy: 0.4390
# Epoch 60/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.8711 - accuracy: 0.2820 - val_loss: 1.7495 - val_accuracy: 0.4270
# Epoch 61/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.8779 - accuracy: 0.2873 - val_loss: 1.7042 - val_accuracy: 0.4370
# Epoch 62/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8468 - accuracy: 0.2975 - val_loss: 1.7144 - val_accuracy: 0.4390
# Epoch 63/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.8637 - accuracy: 0.2860 - val_loss: 1.6903 - val_accuracy: 0.4410
# Epoch 64/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.8394 - accuracy: 0.3005 - val_loss: 1.6798 - val_accuracy: 0.4320
# Epoch 65/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8620 - accuracy: 0.2898 - val_loss: 1.6739 - val_accuracy: 0.4390
# Epoch 66/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8424 - accuracy: 0.2880 - val_loss: 1.7017 - val_accuracy: 0.4400
# Epoch 67/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8427 - accuracy: 0.2905 - val_loss: 1.6621 - val_accuracy: 0.4480
# Epoch 68/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8488 - accuracy: 0.2890 - val_loss: 1.6948 - val_accuracy: 0.4400
# Epoch 69/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8206 - accuracy: 0.3035 - val_loss: 1.6680 - val_accuracy: 0.4380
# Epoch 70/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.8076 - accuracy: 0.3055 - val_loss: 1.6581 - val_accuracy: 0.4250
# Epoch 71/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.8072 - accuracy: 0.3158 - val_loss: 1.6551 - val_accuracy: 0.4340
# Epoch 72/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8167 - accuracy: 0.3005 - val_loss: 1.6410 - val_accuracy: 0.4480
# Epoch 73/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8135 - accuracy: 0.2960 - val_loss: 1.6362 - val_accuracy: 0.4410
# Epoch 74/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.8054 - accuracy: 0.3038 - val_loss: 1.6353 - val_accuracy: 0.4450
# Epoch 75/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.8358 - accuracy: 0.2862 - val_loss: 1.6483 - val_accuracy: 0.4510
# Epoch 76/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.8003 - accuracy: 0.3060 - val_loss: 1.6465 - val_accuracy: 0.4350
# Epoch 77/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7829 - accuracy: 0.3170 - val_loss: 1.6354 - val_accuracy: 0.4570
# Epoch 78/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7822 - accuracy: 0.3178 - val_loss: 1.6157 - val_accuracy: 0.4460
# Epoch 79/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7556 - accuracy: 0.3145 - val_loss: 1.6240 - val_accuracy: 0.4490
# Epoch 80/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7750 - accuracy: 0.3155 - val_loss: 1.6418 - val_accuracy: 0.4500
# Epoch 81/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7659 - accuracy: 0.3058 - val_loss: 1.5984 - val_accuracy: 0.4550
# Epoch 82/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7560 - accuracy: 0.3167 - val_loss: 1.5995 - val_accuracy: 0.4500
# Epoch 83/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7630 - accuracy: 0.3252 - val_loss: 1.6143 - val_accuracy: 0.4480
# Epoch 84/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7512 - accuracy: 0.3210 - val_loss: 1.5946 - val_accuracy: 0.4580
# Epoch 85/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7468 - accuracy: 0.3257 - val_loss: 1.6003 - val_accuracy: 0.4340
# Epoch 86/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7696 - accuracy: 0.3153 - val_loss: 1.6171 - val_accuracy: 0.4560
# Epoch 87/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7373 - accuracy: 0.3212 - val_loss: 1.5954 - val_accuracy: 0.4520
# Epoch 88/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7303 - accuracy: 0.3288 - val_loss: 1.6096 - val_accuracy: 0.4400
# Epoch 89/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7365 - accuracy: 0.3155 - val_loss: 1.5746 - val_accuracy: 0.4590
# Epoch 90/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7187 - accuracy: 0.3310 - val_loss: 1.5721 - val_accuracy: 0.4640
# Epoch 91/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7319 - accuracy: 0.3240 - val_loss: 1.5618 - val_accuracy: 0.4370
# Epoch 92/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.7202 - accuracy: 0.3192 - val_loss: 1.5589 - val_accuracy: 0.4520
# Epoch 93/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.7263 - accuracy: 0.3212 - val_loss: 1.5721 - val_accuracy: 0.4530
# Epoch 94/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.7221 - accuracy: 0.3298 - val_loss: 1.5472 - val_accuracy: 0.4580
# Epoch 95/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.7210 - accuracy: 0.3340 - val_loss: 1.5655 - val_accuracy: 0.4510
# Epoch 96/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6975 - accuracy: 0.3435 - val_loss: 1.5377 - val_accuracy: 0.4510
# Epoch 97/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6990 - accuracy: 0.3315 - val_loss: 1.5406 - val_accuracy: 0.4490
# Epoch 98/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.7101 - accuracy: 0.3307 - val_loss: 1.5520 - val_accuracy: 0.4550
# Epoch 99/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6989 - accuracy: 0.3363 - val_loss: 1.5361 - val_accuracy: 0.4590
# Epoch 100/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6484 - accuracy: 0.3505 - val_loss: 1.5213 - val_accuracy: 0.4540
# Epoch 101/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6894 - accuracy: 0.3385 - val_loss: 1.5235 - val_accuracy: 0.4620
# Epoch 102/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6676 - accuracy: 0.3345 - val_loss: 1.5214 - val_accuracy: 0.4700
# Epoch 103/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6570 - accuracy: 0.3523 - val_loss: 1.5164 - val_accuracy: 0.4690
# Epoch 104/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6631 - accuracy: 0.3370 - val_loss: 1.5527 - val_accuracy: 0.4510
# Epoch 105/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6444 - accuracy: 0.3475 - val_loss: 1.5043 - val_accuracy: 0.4670
# Epoch 106/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6601 - accuracy: 0.3528 - val_loss: 1.5101 - val_accuracy: 0.4600
# Epoch 107/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6474 - accuracy: 0.3470 - val_loss: 1.5175 - val_accuracy: 0.4640
# Epoch 108/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.6519 - accuracy: 0.3505 - val_loss: 1.5229 - val_accuracy: 0.4500
# Epoch 109/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.6411 - accuracy: 0.3435 - val_loss: 1.5234 - val_accuracy: 0.4590
# Epoch 110/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.6448 - accuracy: 0.3557 - val_loss: 1.5210 - val_accuracy: 0.4520
# Epoch 111/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.6235 - accuracy: 0.3560 - val_loss: 1.5129 - val_accuracy: 0.4600
# Epoch 112/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6279 - accuracy: 0.3480 - val_loss: 1.5093 - val_accuracy: 0.4650
# Epoch 113/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6262 - accuracy: 0.3480 - val_loss: 1.5193 - val_accuracy: 0.4500
# Epoch 114/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6300 - accuracy: 0.3610 - val_loss: 1.4957 - val_accuracy: 0.4710
# Epoch 115/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6223 - accuracy: 0.3600 - val_loss: 1.5075 - val_accuracy: 0.4590
# Epoch 116/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6111 - accuracy: 0.3595 - val_loss: 1.4987 - val_accuracy: 0.4640
# Epoch 117/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5984 - accuracy: 0.3610 - val_loss: 1.4976 - val_accuracy: 0.4650
# Epoch 118/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6204 - accuracy: 0.3560 - val_loss: 1.5032 - val_accuracy: 0.4570
# Epoch 119/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6117 - accuracy: 0.3683 - val_loss: 1.5028 - val_accuracy: 0.4560
# Epoch 120/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.6089 - accuracy: 0.3560 - val_loss: 1.4902 - val_accuracy: 0.4620
# Epoch 121/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6042 - accuracy: 0.3620 - val_loss: 1.4860 - val_accuracy: 0.4580
# Epoch 122/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5805 - accuracy: 0.3688 - val_loss: 1.4777 - val_accuracy: 0.4690
# Epoch 123/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5747 - accuracy: 0.3770 - val_loss: 1.4648 - val_accuracy: 0.4660
# Epoch 124/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5745 - accuracy: 0.3760 - val_loss: 1.4923 - val_accuracy: 0.4720
# Epoch 125/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.5717 - accuracy: 0.3742 - val_loss: 1.4704 - val_accuracy: 0.4720
# Epoch 126/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.5816 - accuracy: 0.3720 - val_loss: 1.4675 - val_accuracy: 0.4650
# Epoch 127/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.5626 - accuracy: 0.3652 - val_loss: 1.4784 - val_accuracy: 0.4700
# Epoch 128/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5683 - accuracy: 0.3672 - val_loss: 1.5014 - val_accuracy: 0.4740
# Epoch 129/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5691 - accuracy: 0.3665 - val_loss: 1.4780 - val_accuracy: 0.4710
# Epoch 130/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5495 - accuracy: 0.3877 - val_loss: 1.4717 - val_accuracy: 0.4600
# Epoch 131/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5578 - accuracy: 0.3825 - val_loss: 1.4663 - val_accuracy: 0.4590
# Epoch 132/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5532 - accuracy: 0.3803 - val_loss: 1.5008 - val_accuracy: 0.4470
# Epoch 133/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5540 - accuracy: 0.3905 - val_loss: 1.4697 - val_accuracy: 0.4670
# Epoch 134/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5268 - accuracy: 0.3882 - val_loss: 1.4516 - val_accuracy: 0.4680
# Epoch 135/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5371 - accuracy: 0.3837 - val_loss: 1.4731 - val_accuracy: 0.4640
# Epoch 136/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5084 - accuracy: 0.3972 - val_loss: 1.4578 - val_accuracy: 0.4740
# Epoch 137/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5379 - accuracy: 0.3817 - val_loss: 1.4718 - val_accuracy: 0.4730
# Epoch 138/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.5346 - accuracy: 0.3860 - val_loss: 1.4723 - val_accuracy: 0.4680
# Epoch 139/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5093 - accuracy: 0.3857 - val_loss: 1.5012 - val_accuracy: 0.4490
# Epoch 140/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5144 - accuracy: 0.3893 - val_loss: 1.4645 - val_accuracy: 0.4720
# Epoch 141/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.5009 - accuracy: 0.3955 - val_loss: 1.4663 - val_accuracy: 0.4650
# Epoch 142/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.4956 - accuracy: 0.3927 - val_loss: 1.4462 - val_accuracy: 0.4770
# Epoch 143/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.5095 - accuracy: 0.3975 - val_loss: 1.4491 - val_accuracy: 0.4760
# Epoch 144/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.4977 - accuracy: 0.4022 - val_loss: 1.4639 - val_accuracy: 0.4690
# Epoch 145/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4989 - accuracy: 0.3938 - val_loss: 1.4933 - val_accuracy: 0.4670
# Epoch 146/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.4933 - accuracy: 0.3955 - val_loss: 1.4874 - val_accuracy: 0.4620
# Epoch 147/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.4961 - accuracy: 0.3935 - val_loss: 1.4817 - val_accuracy: 0.4550
# Epoch 148/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.4868 - accuracy: 0.3955 - val_loss: 1.4578 - val_accuracy: 0.4710
# Epoch 149/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4988 - accuracy: 0.3927 - val_loss: 1.4750 - val_accuracy: 0.4660
# Epoch 150/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4708 - accuracy: 0.4098 - val_loss: 1.4794 - val_accuracy: 0.4690
# Epoch 151/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4682 - accuracy: 0.4050 - val_loss: 1.4613 - val_accuracy: 0.4740
# Epoch 152/200
# 125/125 [==============================] - 1s 5ms/step - loss: 1.4699 - accuracy: 0.4075 - val_loss: 1.4579 - val_accuracy: 0.4670
# Epoch 153/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4451 - accuracy: 0.4150 - val_loss: 1.4865 - val_accuracy: 0.4540
# Epoch 154/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4629 - accuracy: 0.4055 - val_loss: 1.4532 - val_accuracy: 0.4730
# Epoch 155/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4525 - accuracy: 0.4153 - val_loss: 1.4506 - val_accuracy: 0.4650
# Epoch 156/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4633 - accuracy: 0.4035 - val_loss: 1.4615 - val_accuracy: 0.4630
# Epoch 157/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4475 - accuracy: 0.4155 - val_loss: 1.4555 - val_accuracy: 0.4670
# Epoch 158/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4491 - accuracy: 0.4040 - val_loss: 1.4619 - val_accuracy: 0.4750
# Epoch 159/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.4509 - accuracy: 0.4145 - val_loss: 1.4501 - val_accuracy: 0.4750
# Epoch 160/200
# 125/125 [==============================] - 1s 8ms/step - loss: 1.4106 - accuracy: 0.4275 - val_loss: 1.4751 - val_accuracy: 0.4590
# Epoch 161/200
# 125/125 [==============================] - 1s 7ms/step - loss: 1.4346 - accuracy: 0.4055 - val_loss: 1.5004 - val_accuracy: 0.4490
# Epoch 162/200
# 125/125 [==============================] - 1s 6ms/step - loss: 1.4511 - accuracy: 0.4085 - val_loss: 1.4699 - val_accuracy: 0.4530

# %% [markdown]
# ❓ **Question: History of your training** ❓
#
# Run the following function on the previous history
# _(keep the default arguments, these are intended for future plots in the notebook)_

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label = 'train' + exp_name)
    ax1.plot(history.history['val_loss'], label = 'val' + exp_name)
    ax1.set_ylim(0., 3)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history=history)
# Out:
# (<Axes: title={'center': 'loss'}>, <Axes: title={'center': 'Accuracy'}>)

# %% [markdown]
# ❓ **Question: Evaluating your CNN** ❓
#
# * Evaluate your model on the test data and compare it with a baseline accuracy.
# * Are you satisfied with this performance?
# * Look at the `PRO TIPS` above and iterate a bit if you want to improve your performance!

# %%
model.evaluate(X_test_small, y_test_small)
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4074 - accuracy: 0.5010
# [1.4074229001998901, 0.5009999871253967]

# %% [markdown]
# ## (3) Increase the size of your training data

# %% [markdown]
# ❓ **Question: train your model on the full dataset** ❓
#
# - Switch to **Colab** if you haven't done it before
# - Make sure to use the **GPU acceleration** by clicking on `Runtime` $\rightarrow$ `Change runtime` $\rightarrow$ `GPU`
#
# 💡 Training neural networks on images (in each batch) can be parallelized, and this **`parallelization procedure`** can be done on **`GPU`**.
#
# ---

# %% [markdown]
# You should observe significant performance improvement
#
# Welcome to the Deep Learning paradigm, where big data makes a significant difference.
#
# But what happens if I can access only a limited amount of pictures? Think about biologists studying rare species. What can they do?
# * To improve the accuracy of a model without much work, we can **generate new data**.
# * The process is called... ⭐️ **`Data Augmentation`** ⭐️ !
# </details>

# %% [markdown]
# ## (4) 🎁📚 Data augmentation

# %% [markdown]
# > ℹ️ This section contains questions and the answers are also provided. Read them carefully before moving on to the `Transfer Learning` challenge.
#
# > 👨🏻‍🏫 If you do not have time to do the `Transfer Learning` challenge, don't worry, we can talk about it during the Recap session, we are aware that this unit about Convolutional Neural Networks is quite packed... but also one of the most exciting applications of Deep Learning ❤️

# %% [markdown]
# * 👩🏻‍🏫 <b><u>Data Augmentation</u></b>
#     * This technique is widely-used and consists of applying little transformations to the input images without changing their labels: ***mirroring***, ***cropping***, ***intensity changes***, etc...
#     * The _improved performance_ simply results from the CNN training with more images (the original pictures + the "augmented" ones).
#
#
# * 👉 <b><u>Theoretically:</u></b>
#     * (1) We could generate these new images by applying some transformations on copies of the original pictures
#     * (2) Train the model on the original images + new images.
#
#
# * 🚨  <b><u>Problem:</u></b>
#     * Such a procedure requires storing all these images in memory...
#     * It can be very intensive, so much so that your computer's RAM cannot hold them all
#
#
# * 🦄 <b><u>In Practice:</u></b>
#     * When a Neural Network operates a forward/backward propagation, it requires to see only 16 pictures at a time if you chose $ batch size = 16 $ for example. It doesn't need to store all the original images or the augmented images in the RAM.
#     * For this reason, we will **augment the data on the fly (batch per batch)**. What does that mean? For every epoch and every batch, during the ***.fit()*** training procedure, we will:
#         1. Generate some `augmented data/images`
#         2. Fit the model on the images and their augmented versions
#         3. Delete the images and their augmented versions from the RAM
#         4. Repeat steps 1-2-3
#
# * 📚 <a href= "https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator"><b><u>tf/keras/preprocessing/image/ImageDataGenerator</u></b></a>

# %% [markdown]
# ❓ **Question: using an ImageDataGenerator** ❓
#
# Look at the following code down below 👇
# * The general syntax may look strange but don't worry:
#     * First, focus on the arguments of the *ImageDataGenerator* which define the augmentation techniques that we are using
#     * Then, check the 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator">**`ImageDataGenerator`**</a> documentation later

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center = False,
    featurewise_std_normalization = False,
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    zoom_range = (0.8, 1.2),
    )

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# ❗️ Always **visualize the augmented images** in order to double-check whether you can still recognize the labels yourself or not ❗️

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()

    if i > 10:
        break

# %% [markdown]
# ❗ **Remarks** ❗
#
# * Each image from **`X_augmented_iterator`** is an ***augmented image*** of one image located in the original `X_train` image dataset
# * This augmentation process is done once per epoch.
# * During one epoch, the model will:
#     1. *create the augmented version* of each picture from `X_train`,
#     2. for each image of `X_train`, *the model will randomly pick either the original version in `X_train` or its augmented version in `X_augmented_iterator`*
#     3. and the model will be *fitted on the combination of some original images + some augmented images*
#
# ---

# %% [markdown]
# ❓ **Question: what is the validation set when we have augmented images** ❓
#
# * Previously, we used the `validation_split` argument to let the model separate the training set into a Train/Validation split when fitting the model for each epoch.
# * It is not possible to use this kind of Train/Val Split here as **using an image in the training set and its transformation in the validation set is considered `data leakage`** !.
# * Therefore, we have to define the **`validation_data`** manually with the following commands: take time to understand the cell down below:👇

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size = 64)

# The early stopping criterion
es = EarlyStopping(patience = 3)

# The fit
history_aug = model_aug.fit(train_flow,
                        epochs = 50,
                        callbacks = [es],
                        validation_data = (X_val, y_val))

# %% [markdown]
# 🚨 The training can be quite long here...
#
# 👉 Feel free to move on to the next exercise and come back to this notebook later to finish the last questions

# %% [markdown]
# ❓ **Question: How did the model with an augmented dataset perform?** ❓
#
# Let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
# YOUR CODE HERE

# %% [markdown]
# 🥡 <b><u>Some takeaways from Data Augmentation:</u></b>
#
# * Data augmentation may not improve your performance easily...
#
# * Here it even decreased the performance!
#
# * Its impact strongly depends on:
#     * the model architecture you used
#     * the learning rate,
#     * the type of augmentation chosen, etc...
#
# * Image classification is an art that requires months and years of practice to master!
#
# 🚨 **Don't spend too much time trying to finetune your model for the moment!  You have other interesting challenges to investigate!** 🚨
#
# 📚 [Here is a good example of a solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/).<br>
# They managed to reach an accuracy level of approx. 80%!

# %% [markdown]
# ---
#
# 🏁 **Congratulations** 🏁
#
# 1. Download this notebook from your `Google Drive` or directly from `Google Colab`
# 2. Drag-and-drop it from your `Downloads` folder to your local challenge folder
#
#
# 💾 Don't forget to push your code
#
# 3. Follow the usual procedure on your terminal, inside the challenge folder:
#       * *git add cifar_classification.ipynb*
#       * *git commit -m "I am the god of CNNs"*
#       * *git push origin master*
#
# *Hint*: To find where this Colab notebook has been saved, click on `File` $\rightarrow$ `Locate in Drive`.
#
# 🚀 It is time to move on to the **Transfer Learning** challenge!
